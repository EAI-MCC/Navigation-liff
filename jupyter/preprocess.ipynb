# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
import os
import time

# %%
####### option ########

# show the structure of HDF5 file and shape of data
file_names = os.listdir('../data/')
print_counter_till_end = 0
for name in file_names:
    if name.find('h5')<0:
        continue
    print('<<<<<<<'+name+'<<<<<<<')
    print_counter_till_end +=1
    with h5py.File('../data/'+name) as f:
        for key in f:
            data_shape =np.array(f[key])
            print(key+' --- '+str(np.shape(f[key])))
            if print_counter_till_end == 1:
                print('  |-- number of attributes = ' + str(len(f[key].attrs.keys())))
#             if name == 'bathroom_01.h5':
# #                 pass
#                 print(np.array(f[key]))

# %%
file_names = os.listdir('../data/')
print_counter_till_end = 0
for name in file_names:
    if name.find('h5')<0:
        continue
    print_counter_till_end +=1
    with h5py.File('../data/'+name) as f:
        data_np_array = np.array(f['location'])
        print(name+' --- '+str(np.shape(data_np_array)[0]))

# %%
for name in file_names:
    if name.find('h5')<0:
        continue
    print_counter_till_end +=1
    with h5py.File('../data/'+name) as f:
        data_np_array = np.array(f['location'])
        data_x = data_np_array[::,0]
    data_y = data_np_array[::,1]
    plt.scatter(data_x,data_y)
    plt.title(name[:-3])
    plt.show()

# %%
# %matplotlib notebook
trajectory = [111, 107, 103, 102, 82, 62, 42, 43, 39, 35, 34, 35, 34, 35, 34, 35, 34, 35, 34, 35, 34, 35, 34, 35, -1, 34, 35, -1, -1, 34, 35, 34, 2, 34, 54, 34, 35, 34, 35, -1, 34, 35, 34, 35, 34, 35, 34, 35, 34, 35, 34, 2, 34, 35, 34, 35, 34, 35, 34, 35, 34, 35, 34, 35, 34, 35, 34, 2, 34, 2, 34, 35, -1, 34, 35, 34, 35, 34, 35, 34, 35, 34, 35, 34, 35]
with h5py.File('../data/'+'bedroom_06.h5') as hf:
    data_np_array = np.array(hf['location'])
    rotation_np_array = np.array(hf['rotation'])
    image_np_array = np.array(hf['observation'])
    graph_np_array = np.array(hf['graph'])
    data_x = data_np_array[::,0]
    data_y = data_np_array[::,1]
    fig = plt.figure()
    ax = fig.add_subplot(111)
    plt.ion()
    plt.scatter(data_x,data_y)
    plt.ylim(-1,9)
    plt.xlim(-1,10)
    fig.show()
    fig.canvas.draw()
    for id in trajectory:
        time.sleep(0.5)
        print(id,'  graph -> ',graph_np_array[id],' location -> ',data_np_array[id])
        ax.clear()
        plt.ylim(-1,9)
        plt.xlim(-1,10)
        current_x =  data_np_array[id,0]
        current_y =  data_np_array[id,1]
        if id == -1:
            ax.scatter(data_x,data_y,c = 'r')
            fig.canvas.draw()
        else:
            angle = rotation_np_array[id]
            plt.scatter(data_x,data_y,c = 'b')
            plt.scatter(current_x,current_y,c = 'r')
            dx = 0.5*np.cos(np.deg2rad(90-angle))
            dy = 0.5*np.sin(np.deg2rad(90-angle))
            plt.scatter(current_x+dx,current_y+dy,c = 'g')
            fig.canvas.draw()

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

m = 100
n = 100
matrix = np.random.normal(0,1,m*n).reshape(m,n)

fig = plt.figure()
ax = fig.add_subplot(111)
plt.ion()

fig.show()
fig.canvas.draw()

for i in range(0,100):
    ax.clear()
    ax.plot(matrix[i,:])
    fig.canvas.draw()

# %%
# %matplotlib notebook
trajectory = [505, 509, 505, 509, 505, 509, 513, 517, 516, 492, 495, -1, 491, 488, 464, 448, 449, -1, 448, 464]
with h5py.File('../data/'+'living_room_01.h5') as hf:
    data_np_array = np.array(hf['location'])
    rotation_np_array = np.array(hf['rotation'])
    image_np_array = np.array(hf['observation'])
    graph_np_array = np.array(hf['graph'])
    data_x = data_np_array[::,0]
    data_y = data_np_array[::,1]
    fig = plt.figure()
    plt.imshow(image_np_array[720])
    fig.canvas.draw()
    
#     for id in trajectory:
#         time.sleep(0.5)
# #         print(id,'  graph -> ',graph_np_array[id],' location -> ',data_np_array[id])
#         ax.clear()
#         plt.ylim(-1,15)
#         plt.xlim(-1,15)
#         current_x =  data_np_array[id,0]
#         current_y =  data_np_array[id,1]
#         if id == -1:
#             ax.scatter(data_x,data_y,c = 'r')
#             fig.canvas.draw()
#         else:
#             angle = rotation_np_array[id]
#             plt.scatter(data_x,data_y,c = 'b')
#             plt.scatter(current_x,current_y,c = 'r')
#             dx = 0.5*np.cos(np.deg2rad(90-angle))
#             dy = 0.5*np.sin(np.deg2rad(90-angle))
#             plt.scatter(current_x+dx,current_y+dy,c = 'g')
#             fig.canvas.draw()
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">
